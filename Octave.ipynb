% %% [markdown]
% ## Testing out Octave in Jupyter

% %%
%Testing octave out in Jupyter
x=-10:0.01:10;
y=sin(x);
plot(x,y)

% %%
[x y z] = sphere(40);
surf(3*x, 3*y, 3*z);
axis equal;
title("Sphere of radius 3");
